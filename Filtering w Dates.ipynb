# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\tcaal\Desktop\Learning Python\Data\WeatherHistory.csv')

# %%
df.head()
# Out:
#   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0      3/26/2006  Mostly Cloudy        rain         5.183333
# 1      3/27/2006  Mostly Cloudy        rain         3.722222
# 2      3/28/2006  Mostly Cloudy        rain         4.855556
# 3      3/29/2006          Foggy        rain         5.211111
# 4      3/30/2006       Overcast        rain         6.255556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  4.111111      0.91             5.5384
# 1                  2.566667      0.94             5.2003
# 2                  3.705556      0.93             5.6189
# 3                  5.211111      0.92             4.7656
# 4                  4.638889      0.92             7.9212
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                     166           9.9820           0               1013.29
# 1                     145           9.9820           0               1013.39
# ...

# %%
df.info() # Describes data set; similar to str() in R
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2363 entries, 0 to 2362
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            2363 non-null   datetime64[us]
#  1   Summary                   2363 non-null   str
#  2   Precip Type               2363 non-null   str
#  3   Temperature (C)           2363 non-null   float64
#  4   Apparent Temperature (C)  2363 non-null   float64
#  5   Humidity                  2363 non-null   float64
#  6   Wind Speed (km/h)         2363 non-null   float64
#  7   Wind Bearing (degrees)    2363 non-null   int64
#  8   Visibility (km)           2363 non-null   float64
#  9   Loud Cover                2363 non-null   int64
#  10  Pressure (millibars)      2363 non-null   float64
#  11  Daily Summary             2363 non-null   str
# dtypes: datetime64[us](1), float64(6), int64(2), str(3)
# memory usage: 221.7 KB

# %%
df['Formatted Date'] = pd.to_datetime(df['Formatted Date']) # Converts type to datetime

# %%
# Date things like string

df[df['Formatted Date'].dt.year == 2006]
# Out:
#     Formatted Date        Summary Precip Type  Temperature (C)  \
# 0       2006-03-26  Mostly Cloudy        rain         5.183333
# 1       2006-03-27  Mostly Cloudy        rain         3.722222
# 2       2006-03-28  Mostly Cloudy        rain         4.855556
# 3       2006-03-29          Foggy        rain         5.211111
# 4       2006-03-30       Overcast        rain         6.255556
# ..             ...            ...         ...              ...
# 213     2006-10-25  Mostly Cloudy        rain        13.033333
# 214     2006-10-26  Mostly Cloudy        rain        17.244444
# 215     2006-10-27  Mostly Cloudy        rain        17.738889
# 216     2006-10-28       Overcast        rain        17.844444
# 217     2006-10-29  Mostly Cloudy        rain        18.861111
#
#      Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                    4.111111      0.91             5.5384
# 1                    2.566667      0.94             5.2003
# ...

# %%
df[df['Formatted Date'].dt.day.name() == 'Monday'] # This didn't work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df[df['Formatted Date'].dt.day.name() == 'Monday']
#
# TypeError: 'str' object is not callable

# %%
df = pd.read_csv("C:/Users/tcaal/Desktop/Learning Python/Data/laptopprices.csv",
                encoding = 'ISO-8859-1')

# %%
df.sort_values(by = 'Price_usd',
                ascending = True)
# Out:
#       ï»¿laptop_ID Company                               Product     TypeName  \
# 1215          1233    Acer      C740-C9QX (3205U/2GB/32GB/Chrome      Netbook
# 20              21    Asus                       Vivobook E200HA      Netbook
# 1120          1135    Vero      V131 (X5-Z8350/4GB/32GB/FHD/W10)     Notebook
# 31              32    Asus  E402WA-GA010T (E2-6110/2GB/32GB/W10)     Notebook
# 290            295    Acer                  Chromebook C910-C2ST     Notebook
# ...            ...     ...                                   ...          ...
# 1066          1081    Asus                            ROG G701VO       Gaming
# 749            758      HP                              Zbook 17  Workstation
# 610            617  Lenovo                          Thinkpad P51     Notebook
# 830            839   Razer                             Blade Pro       Gaming
# 196            200   Razer                             Blade Pro       Gaming
#
# ...

# %%
df[df['Product'] == 'Blade Pro'].sort_values(by = ['Inches','Price_usd'],
                                             ascending = [True,False]) # Sort for product being blade pro and then sort price descending
# Out:
#       ï»¿laptop_ID Company    Product TypeName  Inches  \
# 1231          1249   Razer  Blade Pro   Gaming    14.0
# 778            787   Razer  Blade Pro   Gaming    14.0
# 647            655   Razer  Blade Pro   Gaming    14.0
# 196            200   Razer  Blade Pro   Gaming    17.3
# 830            839   Razer  Blade Pro   Gaming    17.3
#
#                          ScreenResolution                          Cpu   Ram  \
# 1231                    Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 778                     Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 647                     Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 196   4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
# 830   4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
#
#          Memory                      Gpu       OpSys  Weight  Price_usd
# 1231    1TB SSD  Nvidia GeForce GTX 1060  Windows 10  1.95kg     3848.9
# ...
