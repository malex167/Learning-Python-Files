# %%
import pandas as pd
import numpy as np

# %%
my_list = [10,25,35]

# %%
x = np.array(my_list)

# %%
x
# Out:
# array([10, 25, 35])

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    25
# 2    35
# dtype: int64

# %%
type(my_list)
# Out:
# list

# %%
ind_list = ['First','Second','Third']
one = pd.Series(data = my_list, index = ind_list)

# %%
total = one + one

# %%
total
# adding series based on index
# Out:
# First     20
# Second    50
# Third     70
# dtype: int64

# %%
df = pd.DataFrame({'Column 1':one, 'Column 2':one})

# %%
df
# Out:
#         Column 1  Column 2
# First         10        10
# Second        25        25
# Third         35        35
