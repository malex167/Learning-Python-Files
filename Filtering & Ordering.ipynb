# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/tcaal/Desktop/Learning Python/Data/laptopprices.csv")

# %%
df[['Company','Cpu']] # Filtering by columns
# Out:
#      Company                                   Cpu
# 0      Apple                  Intel Core i5 2.3GHz
# 1      Apple                  Intel Core i5 1.8GHz
# 2         HP            Intel Core i5 7200U 2.5GHz
# 3      Apple                  Intel Core i7 2.7GHz
# 4      Apple                  Intel Core i5 3.1GHz
# ...      ...                                   ...
# 1298  Lenovo            Intel Core i7 6500U 2.5GHz
# 1299  Lenovo            Intel Core i7 6500U 2.5GHz
# 1300  Lenovo  Intel Celeron Dual Core N3050 1.6GHz
# 1301      HP            Intel Core i7 6500U 2.5GHz
# 1302    Asus  Intel Celeron Dual Core N3050 1.6GHz
#
# [1303 rows x 2 columns]

# %%
df.iloc[:,[0,1,2]] # Column number
# Out:
#       laptop_ID Company                              Product
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
# [1303 rows x 3 columns]

# %%
df[(df['Company'] == 'Apple') & (df['Ram'] == '16GB')] # Filtering by rows, AND statement
df[(df['Company'] == 'Apple') | (df['Ram'] == '16GB')] # OR statement
# Out:
#       laptop_ID Company            Product            TypeName  Inches  \
# 0             1   Apple        MacBook Pro           Ultrabook    13.3
# 1             2   Apple        Macbook Air           Ultrabook    13.3
# 3             4   Apple        MacBook Pro           Ultrabook    15.4
# 4             5   Apple        MacBook Pro           Ultrabook    13.3
# 6             7   Apple        MacBook Pro           Ultrabook    15.4
# ...         ...     ...                ...                 ...     ...
# 1247       1265    Asus        Rog GL502VS              Gaming    15.6
# 1256       1274    Asus  Rog G752VT-GC073T              Gaming    17.3
# 1271       1289  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1285       1303  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1299       1317  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                          Cpu  \
# ...

# %%
df[df['Company'].isin(['Apple','Dell'])] # IN statement
# Out:
#       laptop_ID Company        Product   TypeName  Inches  \
# 0             1   Apple    MacBook Pro  Ultrabook    13.3
# 1             2   Apple    Macbook Air  Ultrabook    13.3
# 3             4   Apple    MacBook Pro  Ultrabook    15.4
# 4             5   Apple    MacBook Pro  Ultrabook    13.3
# 6             7   Apple    MacBook Pro  Ultrabook    15.4
# ...         ...     ...            ...        ...     ...
# 1278       1296    Dell  Inspiron 3552   Notebook    15.6
# 1281       1299    Dell  Inspiron 3567   Notebook    15.6
# 1290       1308    Dell  Inspiron 3567   Notebook    15.6
# 1292       1310    Dell  Inspiron 3552   Notebook    15.6
# 1295       1313    Dell  Inspiron 3567   Notebook    15.6
#
#                         ScreenResolution  \
# 0     IPS Panel Retina Display 2560x1600
# 1                               1440x900
# 3     IPS Panel Retina Display 2880x1800
# 4     IPS Panel Retina Display 2560x1600
# 6     IPS Panel Retina Display 2880x1800
# ...

# %%
df[df['Price_usd'] > 1500] # Standard expressions
# Out:
#       laptop_ID Company            Product            TypeName  Inches  \
# 3             4   Apple        MacBook Pro           Ultrabook    15.4
# 4             5   Apple        MacBook Pro           Ultrabook    13.3
# 6             7   Apple        MacBook Pro           Ultrabook    15.4
# 8             9    Asus    ZenBook UX430UN           Ultrabook    14.0
# 12           13   Apple        MacBook Pro           Ultrabook    15.4
# ...         ...     ...                ...                 ...     ...
# 1249       1267    Dell             XPS 13  2 in 1 Convertible    13.3
# 1256       1274    Asus  Rog G752VT-GC073T              Gaming    17.3
# 1271       1289  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1285       1303  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1299       1317  Lenovo     Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                          Cpu  \
# ...

# %%
df.loc[df['Company'] == 'Apple'] # Not really used
# Out:
#       laptop_ID Company      Product   TypeName  Inches  \
# 0             1   Apple  MacBook Pro  Ultrabook    13.3
# 1             2   Apple  Macbook Air  Ultrabook    13.3
# 3             4   Apple  MacBook Pro  Ultrabook    15.4
# 4             5   Apple  MacBook Pro  Ultrabook    13.3
# 6             7   Apple  MacBook Pro  Ultrabook    15.4
# 7             8   Apple  Macbook Air  Ultrabook    13.3
# 12           13   Apple  MacBook Pro  Ultrabook    15.4
# 14           15   Apple  MacBook 12"  Ultrabook    12.0
# 15           16   Apple  MacBook Pro  Ultrabook    13.3
# 17           18   Apple  MacBook Pro  Ultrabook    15.4
# 26           27   Apple  MacBook Air  Ultrabook    13.3
# 34           35   Apple  MacBook Air  Ultrabook    13.3
# 45           46   Apple  MacBook Pro  Ultrabook    13.3
# 81           83   Apple  MacBook 12"  Ultrabook    12.0
# 249         254   Apple  MacBook Pro  Ultrabook    13.3
# 270         275   Apple  MacBook Pro  Ultrabook    13.3
# ...

# %%
df.filter(items = [0,5,10,20], axis = 0)
# Out:
#     laptop_ID Company          Product   TypeName  Inches  \
# 0           1   Apple      MacBook Pro  Ultrabook    13.3
# 5           6    Acer         Aspire 3   Notebook    15.6
# 10         11      HP           250 G6   Notebook    15.6
# 20         21    Asus  Vivobook E200HA    Netbook    11.6
#
#                       ScreenResolution                          Cpu  Ram  \
# 0   IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz  8GB
# 5                             1366x768      AMD A9-Series 9420 3GHz  4GB
# 10                            1366x768   Intel Core i5 7200U 2.5GHz  4GB
# 20                            1366x768  Intel Atom x5-Z8350 1.44GHz  2GB
#
#                 Memory                           Gpu       OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640       macOS  1.37kg
# 5            500GB HDD                 AMD Radeon R5  Windows 10   2.1kg
# 10           500GB HDD         Intel HD Graphics 620       No OS  1.86kg
# ...

# %%
# STRINGS

df[df['Product'].str.contains('MacBook')]
# Out:
#       laptop_ID Company      Product   TypeName  Inches  \
# 0             1   Apple  MacBook Pro  Ultrabook    13.3
# 3             4   Apple  MacBook Pro  Ultrabook    15.4
# 4             5   Apple  MacBook Pro  Ultrabook    13.3
# 6             7   Apple  MacBook Pro  Ultrabook    15.4
# 12           13   Apple  MacBook Pro  Ultrabook    15.4
# 14           15   Apple  MacBook 12"  Ultrabook    12.0
# 15           16   Apple  MacBook Pro  Ultrabook    13.3
# 17           18   Apple  MacBook Pro  Ultrabook    15.4
# 26           27   Apple  MacBook Air  Ultrabook    13.3
# 34           35   Apple  MacBook Air  Ultrabook    13.3
# 45           46   Apple  MacBook Pro  Ultrabook    13.3
# 81           83   Apple  MacBook 12"  Ultrabook    12.0
# 249         254   Apple  MacBook Pro  Ultrabook    13.3
# 270         275   Apple  MacBook Pro  Ultrabook    13.3
# 794         803   Apple  MacBook 12"  Ultrabook    12.0
# 1069       1084   Apple  MacBook 12"  Ultrabook    12.0
# ...

# %%
# Does not contain
df[~df['Product'].str.contains('MacBook')]
# Out:
#       laptop_ID Company                              Product  \
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 5             6    Acer                             Aspire 3
# 7             8   Apple                          Macbook Air
# 8             9    Asus                      ZenBook UX430UN
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 1              Ultrabook    13.3                                    1440x900
# ...

# %%
df[(~df['Product'].str.contains('MacBook')) & (df['Memory'].str.contains('SSD'))]
# Out:
#       laptop_ID Company               Product            TypeName  Inches  \
# 2             3      HP                250 G6            Notebook    15.6
# 8             9    Asus       ZenBook UX430UN           Ultrabook    14.0
# 9            10    Acer               Swift 3           Ultrabook    14.0
# 13           14    Dell         Inspiron 3567            Notebook    15.6
# 16           17    Dell         Inspiron 3567            Notebook    15.6
# ...         ...     ...                   ...                 ...     ...
# 1284       1302  Lenovo        Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1285       1303  Lenovo        Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1289       1307    Asus  ZenBook UX305CA-UBM1           Ultrabook    13.3
# 1298       1316  Lenovo        Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299       1317  Lenovo        Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                         Cpu  \
# ...

# %%
df[df['Product'].str.startswith('Mac')] # String methods
df[df['Product'].str.endswith('14')]
# Out:
#      laptop_ID Company        Product  TypeName  Inches ScreenResolution  \
# 300        305    Asus   VivoBook S14  Notebook    14.0         1366x768
# 690        698    Acer  Chromebook 14  Notebook    14.0         1366x768
# 745        753    Acer  Chromebook 14  Notebook    14.0         1366x768
# 949        963    Acer  Chromebook 14  Notebook    14.0         1366x768
#
#                                       Cpu  Ram              Memory  \
# 300            Intel Core i3 7100U 2.4GHz  4GB           128GB SSD
# 690  Intel Celeron Dual Core 3855U 1.6GHz  4GB  32GB Flash Storage
# 745  Intel Celeron Dual Core N3060 1.6GHz  2GB  32GB Flash Storage
# 949  Intel Celeron Dual Core N3060 1.6GHz  4GB  32GB Flash Storage
#
#                        Gpu       OpSys  Weight  Price_usd
# 300  Intel HD Graphics 620  Windows 10   1.3kg      559.9
# 690  Intel HD Graphics 510   Chrome OS  1.45kg      412.5
# 745  Intel HD Graphics 400   Chrome OS  1.68kg      363.0
# ...

# %%
df[df['Price_usd'].duplicated()]
# Out:
#       laptop_ID Company                                  Product  \
# 37           38    Dell                            Inspiron 5770
# 44           45    Dell                            Inspiron 7773
# 56           57      HP  15-bs002nv (i3-6006U/4GB/128GB/FHD/W10)
# 60           61    Dell                            Inspiron 5770
# 61           62    Dell                              Vostro 5471
# ...         ...     ...                                      ...
# 1298       1316  Lenovo                           Yoga 500-14ISK
# 1299       1317  Lenovo                           Yoga 900-13ISK
# 1300       1318  Lenovo                       IdeaPad 100S-14IBR
# 1301       1319      HP      15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus      X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 37              Notebook    17.3                 IPS Panel Full HD 1920x1080
# ...

# %%
df[df['Product'].str.match('Mac.*Air')] # Start with Mac and end with Air using .*
# Out:
#       laptop_ID Company      Product   TypeName  Inches ScreenResolution  \
# 1             2   Apple  Macbook Air  Ultrabook    13.3         1440x900
# 7             8   Apple  Macbook Air  Ultrabook    13.3         1440x900
# 26           27   Apple  MacBook Air  Ultrabook    13.3         1440x900
# 34           35   Apple  MacBook Air  Ultrabook    13.3         1440x900
# 1234       1252   Apple  MacBook Air  Ultrabook    11.6         1366x768
#
#                        Cpu  Ram               Memory                     Gpu  \
# 1     Intel Core i5 1.8GHz  8GB  128GB Flash Storage  Intel HD Graphics 6000
# 7     Intel Core i5 1.8GHz  8GB  256GB Flash Storage  Intel HD Graphics 6000
# 26    Intel Core i5 1.6GHz  8GB  128GB Flash Storage  Intel HD Graphics 6000
# 34    Intel Core i5 1.6GHz  8GB  256GB Flash Storage  Intel HD Graphics 6000
# 1234  Intel Core i5 1.6GHz  4GB  256GB Flash Storage  Intel HD Graphics 6000
#
#          OpSys  Weight  Price_usd
# ...
